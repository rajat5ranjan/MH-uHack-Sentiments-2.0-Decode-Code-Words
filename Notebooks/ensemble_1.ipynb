# %%
import pandas as pd
import numpy as np

kv_1 = pd.read_csv('mh-transformers-v10.csv') #2.82 roberta
kv_2 = pd.read_csv('mh-transformers-v13.csv') #2.85 bert
kv_3 = pd.read_csv('mh-transformers-v14.csv') #2.85 roberta more seq len

# %%
target = ['Components', 'Delivery and Customer Support',
       'Design and Aesthetics', 'Dimensions', 'Features', 'Functionality',
       'Installation', 'Material', 'Price', 'Quality', 'Usability',
       'Polarity']

kv_3[target]
# Out:
#       Components  Delivery and Customer Support  Design and Aesthetics  \
# 0       0.012784                       0.010631               0.006187
# 1       0.003646                       0.001442               0.002969
# 2       0.003722                       0.002351               0.004181
# 3       0.002539                       0.001153               0.002156
# 4       0.001915                       0.001010               0.003676
# ...          ...                            ...                    ...
# 2626    0.011940                       0.004520               0.015771
# 2627    0.042346                       0.002167               0.615088
# 2628    0.003119                       0.002550               0.002566
# 2629    0.006639                       0.005044               0.965234
# 2630    0.005585                       0.002954               0.005465
#
#       Dimensions  Features  Functionality  Installation  Material     Price  \
# ...

# %%
kv_3[target].describe()
# Out:
#         Components  Delivery and Customer Support  Design and Aesthetics  \
# count  2631.000000                    2631.000000            2631.000000
# mean      0.048862                       0.034766               0.105417
# std       0.160583                       0.155486               0.268013
# min       0.001415                       0.000608               0.000972
# 25%       0.003995                       0.002034               0.003864
# 50%       0.006738                       0.003285               0.007031
# 75%       0.013696                       0.005989               0.018961
# max       0.994629                       0.993359               0.996875
#
#         Dimensions     Features  Functionality  Installation     Material  \
# count  2631.000000  2631.000000    2631.000000   2631.000000  2631.000000
# mean      0.121208     0.057005       0.441923      0.133238     0.035228
# std       0.292815     0.176947       0.452183      0.316351     0.143920
# ...

# %%
# np.clip(kv_1['Components'],a_max=0.99, a_min=0.01)
kv_1[target] = kv_1[target]*0.6+kv_2[target]*0.25+kv_3[target]*0.15

# %%
kv_1.describe()
# Out:
#         Components  Delivery and Customer Support  Design and Aesthetics  \
# count  2631.000000                    2631.000000            2631.000000
# mean      0.047737                       0.033687               0.097501
# std       0.161576                       0.153371               0.256052
# min       0.001132                       0.000666               0.001553
# 25%       0.002873                       0.001715               0.003114
# 50%       0.004791                       0.002813               0.005611
# 75%       0.010184                       0.005086               0.014643
# max       0.951959                       0.972784               0.993251
#
#         Dimensions     Features  Functionality  Installation     Material  \
# count  2631.000000  2631.000000    2631.000000   2631.000000  2631.000000
# mean      0.121998     0.054922       0.433012      0.130690     0.031940
# std       0.293531     0.172228       0.452504      0.315147     0.134669
# ...

# %%
kv_1.to_csv('mh_transformer-v10_6_v13_25_v14_15.csv',index=False) #2.76933
